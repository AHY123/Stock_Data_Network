# %%
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels as sm
from pathlib import Path
import yfinance as yf
from tqdm import tqdm

from correlation_helper import *

# %%
market_ticker = '^GSPC'
start_analysis = '2023-01-01'
end_analysis = '2025-05-13'
data_path = Path(f'../data/snp500_stock_2023_cleaned.csv').resolve()
data = pd.read_csv(data_path)
data
# Out:
#            Date           A        AAPL        ABBV        ABNB         ABT  \
# 0    2023-01-03  147.617630  123.470604  147.798233   84.900002  104.295929
# 1    2023-01-04  149.221283  124.744125  148.990585   88.720001  105.847336
# 2    2023-01-05  149.654190  123.421265  148.808548   87.709999  105.457100
# 3    2023-01-06  145.285889  127.962418  151.593781   88.519997  106.913322
# 4    2023-01-09  145.089111  128.485657  147.142868   89.239998  106.741997
# ..          ...         ...         ...         ...         ...         ...
# 587  2025-05-07  107.519997  195.992981  188.089996  123.120003  133.949997
# 588  2025-05-08  108.699997  197.231369  185.580002  126.389999  134.000000
# 589  2025-05-09  106.930000  198.270004  184.600006  127.040001  133.240005
# 590  2025-05-12  115.550003  210.789993  190.070007  134.210007  131.990005
# 591  2025-05-13  115.419998  212.929993  188.000000  138.050003  129.050003
#
# ...

# %%
market_returns = standardize(pct_change(yf.download(market_ticker, start=start_analysis, end=end_analysis)['Close'].to_numpy().flatten()))
market_returns
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['^GSPC']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='guce.yahoo.com', port=443): Read timed out. (read timeout=30)"))
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 market_returns = standardize(pct_change(yf.download(market_ticker, start=start_analysis, end=end_analysis)['Close'].to_numpy().flatten()))
#       2 market_returns
#
# ZeroDivisionError: division by zero
