# %%
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels as sm
from pathlib import Path
import yfinance as yf
from tqdm import tqdm

from correlation_helper import *

# %%
num_top = 50
num_vote = 20
corr_type = 'beta'
target = 'USGO'
interval = '3D'

company_path = Path(f'../data/top_{num_top}_companies_by_sector.csv').resolve()
corr_path = Path(f'../data/{corr_type}_matrix_2024-01-01_2025-01-01_top{num_top}.csv').resolve()

analysis_start = '2024-01-01'
analysis_end = '2024-12-31'

# %%
company = pd.read_csv(company_path)
corr = pd.read_csv(corr_path).set_index('Ticker')[[target]]
corr
# Out:
#             USGO
# Ticker
# UFPI   -0.464907
# HYMC    0.602544
# ABAT   -0.188233
# HYMCL  -0.257207
# USAU    0.559888
# ...          ...
# INFN   -0.379417
# CDZIP   0.369749
# NNE          NaN
# NWE    -0.687845
# ALCE    0.683092
#
# [509 rows x 1 columns]

# %%
corr_data = (corr
             .assign(abs_corr = corr[target].abs())
             .dropna()
             .sort_values(by='abs_corr', ascending=False)
             )
corr_data = corr_data[corr_data[target] < 1][:num_vote]
print(f'Number of positive: {len(corr_data[corr_data[target] > 0])}')
print(f'Number of negative: {len(corr_data[corr_data[target] < 0])}')
corr_data
# Out:
# Number of positive: 19
# Number of negative: 1
#             USGO  abs_corr
# Ticker
# HOLX    0.949133  0.949133
# CHRD    0.940426  0.940426
# PCVX    0.929393  0.929393
# HALO    0.928119  0.928119
# PRDO    0.913779  0.913779
# WSC     0.908697  0.908697
# EXAS    0.908288  0.908288
# AFRM    0.907148  0.907148
# ARLP    0.902322  0.902322
# TPG     0.885059  0.885059
# LFUS    0.880614  0.880614
# INCY    0.875026  0.875026
# CPRT    0.846967  0.846967
# FYBR    0.834946  0.834946
# CDZI    0.833366  0.833366
# PNFP    0.829515  0.829515
# KLXE    0.824289  0.824289
# HPKEW  -0.823464  0.823464
# CSX     0.807642  0.807642
# EWBC    0.803350  0.803350

# %%
corr_stock = yf.download(
    [target]+ corr_data.index.tolist(),
    start=analysis_end,
    ).dropna(axis=1, how='all')['Close']
corr_stock.index = pd.to_datetime(corr_stock.index)
corr_stock = corr_stock.resample(interval).last().dropna()
corr_stock
# Out:
# [*********************100%***********************]  21 of 21 completed
# Ticker           AFRM       ARLP  CDZI        CHRD       CPRT        CSX  \
# Date
# 2024-12-31  62.509998  25.944275  5.07  118.889999  56.320000  32.029392
# 2025-01-03  66.500000  25.905275  5.12  120.949997  56.910000  32.208660
# 2025-01-06  58.669998  25.768778  4.67  122.599998  56.779999  32.069229
# 2025-01-09  55.310001  26.509766  5.12  123.779999  55.639999  31.650934
# 2025-01-12  55.349998  26.412266  4.96  126.699997  56.220001  32.009472
# 2025-01-15  57.990002  27.163004  5.17  126.309998  56.900002  32.597076
# 2025-01-21  56.759998  28.157484  4.89  120.739998  57.610001  33.533257
# 2025-01-24  55.730000  28.508478  4.54  117.459999  57.700001  32.557236
# 2025-01-27  58.950001  28.069736  4.79  116.769997  57.320000  32.846062
# 2025-01-09  False  ...  False  False   True  False   True  False  False
# 2025-01-12   True  ...   True   True   True  False  False   True   True
#
# Ticker        TPG   USGO    WSC
# Date
# 2024-12-31  False  False  False
# 2025-01-03   True   True   True
# 2025-01-06  False  False   True
# 2025-01-09  False   True   True
# 2025-01-12   True  False   True
#
# [5 rows x 21 columns]

# %%
target_trend = stock_diff[target]
relate_vote = stock_diff.drop(columns=[target])
relate_vote = relate_vote.transform(lambda col: col if corr[target][col.name] > 0 else -col, axis=0)
relate_vote.head()
# Out:
# Ticker       AFRM   ARLP   CDZI   CHRD   CPRT    CSX   EWBC   EXAS   FYBR  \
# Date
# 2024-12-31  False  False  False  False  False  False  False  False  False
# 2025-01-03   True  False   True   True   True   True   True   True   True
# 2025-01-06  False  False  False   True  False  False  False  False   True
# 2025-01-09  False   True   True   True  False  False  False  False  False
# 2025-01-12   True  False  False   True   True   True   True  False   True
#
# Ticker       HALO   HOLX  HPKEW   INCY   KLXE   LFUS   PCVX   PNFP   PRDO  \
# Date
# 2024-12-31  False  False   True  False  False  False  False  False  False
# 2025-01-03  False   True  False   True  False   True   True   True  False
# 2025-01-06   True  False   True   True  False  False  False   True   True
# 2025-01-09  False  False   True  False   True  False   True  False  False
# 2025-01-12   True  False  False   True   True  False  False   True   True
#
# Ticker        TPG    WSC
# Date
# 2024-12-31  False  False
# 2025-01-03   True   True
# 2025-01-06  False   True
# 2025-01-09  False   True
# 2025-01-12   True   True

# %%
votes = (relate_vote.mean(axis=1) - 0.5) * 200
votes = votes.rename('votes')
votes
# Out:
# Date
# 2024-12-31   -90.0
# 2025-01-03    50.0
# 2025-01-06   -20.0
# 2025-01-09   -30.0
# 2025-01-12    30.0
# 2025-01-15    70.0
# 2025-01-21    50.0
# 2025-01-24     0.0
# 2025-01-27    10.0
# 2025-01-30     0.0
# 2025-02-02   -40.0
# 2025-02-05   -20.0
# 2025-02-08    20.0
# 2025-02-11   -20.0
# 2025-02-14     0.0
# 2025-02-17     0.0
# 2025-02-20   -60.0
# 2025-02-23   -30.0
# 2025-02-26    10.0
# 2025-03-01   -70.0
# 2025-03-04   -50.0
# Name: votes, dtype: float64

# %%
results = pd.concat([target_trend, votes], axis=1)
results = results.assign(power = votes.abs())
# for t in [20]:
for t in range(10, 91, 5):
    direction = results['votes'] > 0
    is_vote = (results[target] == direction) & (results['power'] >= t)
    # is_vote = (results['power'] > t)
    guess = results[target][is_vote]

    # results[f'direction_{t}'] = direction
    # results[f'is_vote_{t}'] = is_vote
    results[f'guess_{t}'] = guess
    results[f'shift_{t}'] = results[f'guess_{t}'].shift(1)
    results[f'out_{t}'] = results[f'shift_{t}'] == results[target]
    results[f'out_{t}'] = results[f'out_{t}'][~results[f'shift_{t}'].isna()]
    results[f'inc_{t}'] = results[f'out_{t}'][~results[f'shift_{t}'].isna()][results[f'shift_{t}'] == True]
    results[f'dec_{t}'] = results[f'out_{t}'][~results[f'shift_{t}'].isna()][results[f'shift_{t}'] == False]
    results = results.drop(columns = [f'guess_{t}', f'shift_{t}'])
results
# Out:
#              USGO  votes  power out_10 inc_10 dec_10 out_15 inc_15 dec_15  \
# Date
# 2024-12-31  False  -90.0   90.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-03   True   50.0   50.0  False    NaN  False  False    NaN  False
# 2025-01-06  False  -20.0   20.0  False  False    NaN  False  False    NaN
# 2025-01-09   True  -30.0   30.0  False    NaN  False  False    NaN  False
# 2025-01-12  False   30.0   30.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-15   True   70.0   70.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-21  False   50.0   50.0  False  False    NaN  False  False    NaN
# 2025-01-24   True    0.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-27   True   10.0   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-30   True    0.0    0.0   True   True    NaN    NaN    NaN    NaN
# 2025-02-02   True  -40.0   40.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-05  False  -20.0   20.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-08   True   20.0   20.0  False    NaN  False  False    NaN  False
# 2025-02-11   True  -20.0   20.0   True   True    NaN   True   True    NaN
# 2025-02-14  False    0.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-17   True    0.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-20  False  -60.0   60.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-23  False  -30.0   30.0   True    NaN   True   True    NaN   True
# 2025-02-26  False   10.0   10.0   True    NaN   True   True    NaN   True
# 2025-03-01  False  -70.0   70.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-03-04  False  -50.0   50.0   True    NaN   True   True    NaN   True
#
#            out_20  ... dec_75 out_80 inc_80 dec_80 out_85 inc_85 dec_85  \
# Date               ...
# 2024-12-31    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-03  False  ...  False  False    NaN  False  False    NaN  False
# 2025-01-06  False  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-09    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-12    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-15    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-21  False  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-24    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-27    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-30    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-02    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-05    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-08    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-11    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-14    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-17    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-20    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-23   True  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-26   True  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-03-01    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-03-04   True  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#            out_90 inc_90 dec_90
# Date
# 2024-12-31    NaN    NaN    NaN
# 2025-01-03  False    NaN  False
# 2025-01-06    NaN    NaN    NaN
# 2025-01-09    NaN    NaN    NaN
# 2025-01-12    NaN    NaN    NaN
# 2025-01-15    NaN    NaN    NaN
# 2025-01-21    NaN    NaN    NaN
# 2025-01-24    NaN    NaN    NaN
# 2025-01-27    NaN    NaN    NaN
# 2025-01-30    NaN    NaN    NaN
# 2025-02-02    NaN    NaN    NaN
# 2025-02-05    NaN    NaN    NaN
# 2025-02-08    NaN    NaN    NaN
# 2025-02-11    NaN    NaN    NaN
# 2025-02-14    NaN    NaN    NaN
# 2025-02-17    NaN    NaN    NaN
# 2025-02-20    NaN    NaN    NaN
# 2025-02-23    NaN    NaN    NaN
# 2025-02-26    NaN    NaN    NaN
# 2025-03-01    NaN    NaN    NaN
# 2025-03-04    NaN    NaN    NaN
#
# [21 rows x 54 columns]

# %%
final = pd.concat([
    results.loc[:, results.columns.str.contains('out')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('inc')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('dec')].mean(axis=0).reset_index(drop=True),
], axis=1, ignore_index=True)
final.columns = ['out', 'inc', 'dec']
final.index = results.loc[:, results.columns.str.contains('out')].mean(axis=0).index.str.replace('out_', '')
final
# Out:
#          out       inc       dec
# 10       0.5       0.5       0.5
# 15  0.444444  0.333333       0.5
# 20       0.5       0.0      0.75
# 25       0.5       0.0      0.75
# 30       0.5       0.0      0.75
# 35       0.4       0.0  0.666667
# 40       0.4       0.0  0.666667
# 45       0.4       0.0  0.666667
# 50       0.4       0.0  0.666667
# 55       0.5       0.0  0.666667
# 60       0.5       0.0  0.666667
# 65  0.333333       0.0       0.5
# 70  0.333333       0.0       0.5
# 75       0.0       NaN       0.0
# 80       0.0       NaN       0.0
# 85       0.0       NaN       0.0
# 90       0.0       NaN       0.0

# %%
decrease_power = -10
increase_power = 50

results = pd.concat([target_trend, votes], axis=1)
results = results.assign(power = votes.abs())

direction = results['votes'] > 0
is_vote = (
    (results[target] == False) & (results['votes'] <= decrease_power) |
    (results[target] == True) & (results['votes'] >= increase_power)
)
# is_vote = (results[target] == direction) & (results['power'] > t)
guess = results[target][is_vote]

# results[f'direction_{t}'] = direction
# results[f'is_vote_{t}'] = is_vote
results[f'guess'] = guess
results[f'shift'] = results[f'guess'].shift(1)
results[f'out'] = results[f'shift'] == results[target]
results[f'out'] = results[f'out'][~results[f'shift'].isna()]
results[f'inc'] = results[f'out'][results[f'shift'] == True]
results[f'dec'] = results[f'out'][results[f'shift'] == False]
results = results.drop(columns = [f'guess', f'shift'])
results
# Out:
#              USGO  votes  power    out    inc    dec
# Date
# 2024-12-31  False  -90.0   90.0    NaN    NaN    NaN
# 2025-01-03   True   50.0   50.0  False    NaN  False
# 2025-01-06  False  -20.0   20.0  False  False    NaN
# 2025-01-09   True  -30.0   30.0  False    NaN  False
# 2025-01-12  False   30.0   30.0    NaN    NaN    NaN
# 2025-01-15   True   70.0   70.0    NaN    NaN    NaN
# 2025-01-21  False   50.0   50.0  False  False    NaN
# 2025-01-24   True    0.0    0.0    NaN    NaN    NaN
# 2025-01-27   True   10.0   10.0    NaN    NaN    NaN
# 2025-01-30   True    0.0    0.0    NaN    NaN    NaN
# 2025-02-02   True  -40.0   40.0    NaN    NaN    NaN
# 2025-02-05  False  -20.0   20.0    NaN    NaN    NaN
# 2025-02-08   True   20.0   20.0  False    NaN  False
# 2025-02-11   True  -20.0   20.0    NaN    NaN    NaN
# 2025-02-14  False    0.0    0.0    NaN    NaN    NaN
# 2025-02-17   True    0.0    0.0    NaN    NaN    NaN
# 2025-02-20  False  -60.0   60.0    NaN    NaN    NaN
# 2025-02-23  False  -30.0   30.0   True    NaN   True
# 2025-02-26  False   10.0   10.0   True    NaN   True
# 2025-03-01  False  -70.0   70.0    NaN    NaN    NaN
# 2025-03-04  False  -50.0   50.0   True    NaN   True

# %%
final = pd.concat([
    results.loc[:, results.columns.str.contains('out')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('inc')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('dec')].mean(axis=0).reset_index(drop=True),
], axis=1, ignore_index=True)
final.columns = ['out', 'inc', 'dec']
final.index = results.loc[:, results.columns.str.contains('out')].mean(axis=0).index.str.replace('out_', '')
final
# Out:
#        out  inc  dec
# out  0.375  0.0  0.5
