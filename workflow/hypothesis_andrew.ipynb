# %%
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels as sm
from pathlib import Path
import yfinance as yf
from tqdm import tqdm

from correlation_helper import *

# %%
num_top = 50
num_vote = 20
corr_type = 'beta'
target = 'AAPL'
interval = '3D'

company_path = Path(f'../data/top_{num_top}_companies_by_sector.csv').resolve()
corr_path = Path(f'../data/{corr_type}_matrix_2024-01-01_2025-01-01_top{num_top}.csv').resolve()

analysis_start = '2024-01-01'
analysis_end = '2024-12-31'

# %%
company = pd.read_csv(company_path)
corr = pd.read_csv(corr_path).set_index('Ticker')[[target]]
corr
# Out:
#             AAPL
# Ticker
# UFPI   -0.034487
# HYMC    0.269600
# ABAT    0.849086
# HYMCL  -0.385371
# USAU    0.761102
# ...          ...
# INFN    0.690865
# CDZIP   0.576359
# NNE          NaN
# NWE    -0.184580
# ALCE    0.142255
#
# [509 rows x 1 columns]

# %%
corr_data = (corr
             .assign(abs_corr = corr[target].abs())
             .dropna()
             .sort_values(by='abs_corr', ascending=False)
             )
corr_data = corr_data[corr_data[target] < 1][:num_vote]
print(f'Number of positive: {len(corr_data[corr_data[target] > 0])}')
print(f'Number of negative: {len(corr_data[corr_data[target] < 0])}')
corr_data
# Out:
# Number of positive: 20
# Number of negative: 0
#             AAPL  abs_corr
# Ticker
# DDOG    0.980256  0.980256
# GFS     0.980213  0.980213
# OPCH    0.976043  0.976043
# LRCX    0.975052  0.975052
# HST     0.974054  0.974054
# WING    0.970883  0.970883
# AVGO    0.970879  0.970879
# MKSI    0.968285  0.968285
# MSFT    0.966605  0.966605
# FFIV    0.965774  0.965774
# ROIC    0.962915  0.962915
# TXN     0.962611  0.962611
# SBRA    0.955705  0.955705
# ROAD    0.954248  0.954248
# REG     0.953828  0.953828
# MCHP    0.951965  0.951965
# MIDD    0.949858  0.949858
# KLAC    0.946578  0.946578
# POOL    0.945770  0.945770
# LLYVK   0.943874  0.943874

# %%
corr_stock = yf.download(
    [target]+ corr_data.index.tolist(),
    start=analysis_end,
    ).dropna(axis=1, how='all')['Close']
corr_stock.index = pd.to_datetime(corr_stock.index)
corr_stock = corr_stock.resample(interval).last().dropna()
corr_stock
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  21 of 21 completed
# Ticker            AAPL        AVGO        DDOG        FFIV        GFS  \
# Date
# 2024-12-31  243.582199  231.979996  143.630005  251.750000  42.480000
# 2025-01-03  243.092728  232.550003  144.830002  254.360001  43.180000
# 2025-01-06  242.433441  229.309998  141.880005  258.839996  41.619999
# 2025-01-09  236.589874  224.309998  140.419998  254.320007  40.959999
# 2025-01-12  233.023788  224.699997  139.160004  258.109985  41.169998
# 2025-01-15  229.727417  237.440002  138.399994  263.950012  43.099998
# 2025-01-21  223.414368  240.279999  140.199997  272.910004  41.669998
# 2025-01-24  222.535324  244.699997  140.990005  272.989990  41.669998
# 2025-01-27  239.097122  206.350006  145.720001  300.459991  41.380001
# 2025-01-30  235.740814  221.270004  142.710007  297.260010  41.470001
# 2025-01-24  84.459999  17.440001  16.615685  184.158173  279.829987
# 2025-01-27  79.309998  17.450001  16.281799  178.946716  303.700012
# 2025-01-30  80.400002  17.469999  16.409460  184.610001  297.899994
# 2025-02-02  81.949997  17.469999  16.419281  180.559998  306.929993
# 2025-02-05  86.760002  17.480000  16.389822  180.000000  304.920013
# 2025-02-08  81.620003  17.500000  16.330898  180.309998  308.480011
# 2025-02-11  78.430000  17.490000  16.380001  180.800003  311.929993
#
# [14 rows x 21 columns]

# %%
stock_diff = corr_stock.pct_change(axis=0).apply(lambda x: x >= 0).dropna()
stock_diff.head()
# Out:
# Ticker       AAPL   AVGO   DDOG   FFIV    GFS    HST   KLAC  LLYVK   LRCX  \
# Date
# 2024-12-31  False  False  False  False  False  False  False  False  False
# 2025-01-03  False   True   True   True   True   True   True  False   True
# 2025-01-06  False  False  False   True  False  False   True  False   True
# 2025-01-09  False  False  False  False  False   True  False  False  False
# 2025-01-12  False   True  False   True   True   True   True   True   True
#
# Ticker       MCHP  ...   MKSI   MSFT   OPCH   POOL    REG   ROAD   ROIC  \
# Date               ...
# 2024-12-31  False  ...  False  False  False  False  False  False  False
# 2025-01-03   True  ...   True   True   True   True   True   True   True
# 2025-01-06  False  ...   True   True   True  False  False  False   True
# 2025-01-09  False  ...  False  False  False   True  False  False  False
# 2025-01-12   True  ...   True  False   True   True   True  False   True
#
# Ticker       SBRA    TXN   WING
# Date
# 2024-12-31  False  False  False
# 2025-01-03   True   True   True
# 2025-01-06  False   True  False
# 2025-01-09  False  False  False
# 2025-01-12   True   True  False
#
# [5 rows x 21 columns]

# %%
target_trend = stock_diff[target]
relate_vote = stock_diff.drop(columns=[target])
relate_vote = relate_vote.transform(lambda col: col if corr[target][col.name] > 0 else -col, axis=0)
relate_vote.head()
# Out:
# Ticker       AVGO   DDOG   FFIV    GFS    HST   KLAC  LLYVK   LRCX   MCHP  \
# Date
# 2024-12-31  False  False  False  False  False  False  False  False  False
# 2025-01-03   True   True   True   True   True   True  False   True   True
# 2025-01-06  False  False   True  False  False   True  False   True  False
# 2025-01-09  False  False  False  False   True  False  False  False  False
# 2025-01-12   True  False   True   True   True   True   True   True   True
#
# Ticker       MIDD   MKSI   MSFT   OPCH   POOL    REG   ROAD   ROIC   SBRA  \
# Date
# 2024-12-31  False  False  False  False  False  False  False  False  False
# 2025-01-03   True   True   True   True   True   True   True   True   True
# 2025-01-06   True   True   True   True  False  False  False   True  False
# 2025-01-09  False  False  False  False   True  False  False  False  False
# 2025-01-12   True   True  False   True   True   True  False   True   True
#
# Ticker        TXN   WING
# Date
# 2024-12-31  False  False
# 2025-01-03   True   True
# 2025-01-06   True  False
# 2025-01-09  False  False
# 2025-01-12   True  False

# %%
votes = (relate_vote.mean(axis=1) - 0.5) * 200
votes = votes.rename('votes')
votes
# Out:
# Date
# 2024-12-31   -100.0
# 2025-01-03     90.0
# 2025-01-06    -10.0
# 2025-01-09    -80.0
# 2025-01-12     60.0
# 2025-01-15     60.0
# 2025-01-21     50.0
# 2025-01-24      0.0
# 2025-01-27    -30.0
# 2025-01-30     30.0
# 2025-02-02    -10.0
# 2025-02-05    -10.0
# 2025-02-08     50.0
# 2025-02-11     30.0
# Name: votes, dtype: float64

# %%
results = pd.concat([target_trend, votes], axis=1)
results = results.assign(power = votes.abs())
# for t in [20]:
for t in range(10, 91, 5):
    direction = results['votes'] > 0
    is_vote = (results[target] == direction) & (results['power'] >= t)
    # is_vote = (results['power'] > t)
    guess = results[target][is_vote]

    # results[f'direction_{t}'] = direction
    # results[f'is_vote_{t}'] = is_vote
    results[f'guess_{t}'] = guess
    results[f'shift_{t}'] = results[f'guess_{t}'].shift(1)
    results[f'out_{t}'] = results[f'shift_{t}'] == results[target]
    results[f'out_{t}'] = results[f'out_{t}'][~results[f'shift_{t}'].isna()]
    results[f'inc_{t}'] = results[f'out_{t}'][~results[f'shift_{t}'].isna()][results[f'shift_{t}'] == True]
    results[f'dec_{t}'] = results[f'out_{t}'][~results[f'shift_{t}'].isna()][results[f'shift_{t}'] == False]
    results = results.drop(columns = [f'guess_{t}', f'shift_{t}'])
results
# Out:
#              AAPL  votes  power out_10 inc_10 dec_10 out_15 inc_15 dec_15  \
# Date
# 2024-12-31  False -100.0  100.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-03  False   90.0   90.0   True    NaN   True   True    NaN   True
# 2025-01-06  False  -10.0   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-09  False  -80.0   80.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-12  False   60.0   60.0   True    NaN   True   True    NaN   True
# 2025-01-15  False   60.0   60.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-21  False   50.0   50.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-24  False    0.0    0.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-27   True  -30.0   30.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-30  False   30.0   30.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-02  False  -10.0   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-05  False  -10.0   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-08   True   50.0   50.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-11   True   30.0   30.0   True   True    NaN   True   True    NaN
#
#            out_20  ... dec_75 out_80 inc_80 dec_80 out_85 inc_85 dec_85  \
# Date               ...
# 2024-12-31    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-03   True  ...   True   True    NaN   True   True    NaN   True
# 2025-01-06    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-09    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-12   True  ...   True   True    NaN   True    NaN    NaN    NaN
# 2025-01-15    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-21    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-24    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-27    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-01-30    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-02    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-05    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-08    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2025-02-11   True  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#            out_90 inc_90 dec_90
# Date
# 2024-12-31    NaN    NaN    NaN
# 2025-01-03   True    NaN   True
# 2025-01-06    NaN    NaN    NaN
# 2025-01-09    NaN    NaN    NaN
# 2025-01-12    NaN    NaN    NaN
# 2025-01-15    NaN    NaN    NaN
# 2025-01-21    NaN    NaN    NaN
# 2025-01-24    NaN    NaN    NaN
# 2025-01-27    NaN    NaN    NaN
# 2025-01-30    NaN    NaN    NaN
# 2025-02-02    NaN    NaN    NaN
# 2025-02-05    NaN    NaN    NaN
# 2025-02-08    NaN    NaN    NaN
# 2025-02-11    NaN    NaN    NaN
#
# [14 rows x 54 columns]

# %%
final = pd.concat([
    results.loc[:, results.columns.str.contains('out')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('inc')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('dec')].mean(axis=0).reset_index(drop=True),
], axis=1, ignore_index=True)
final.columns = ['out', 'inc', 'dec']
final.index = results.loc[:, results.columns.str.contains('out')].mean(axis=0).index.str.replace('out_', '')
final
# Out:
#     out  inc  dec
# 10  1.0  1.0  1.0
# 15  1.0  1.0  1.0
# 20  1.0  1.0  1.0
# 25  1.0  1.0  1.0
# 30  1.0  1.0  1.0
# 35  1.0  1.0  1.0
# 40  1.0  1.0  1.0
# 45  1.0  1.0  1.0
# 50  1.0  1.0  1.0
# 55  1.0  NaN  1.0
# 60  1.0  NaN  1.0
# 65  1.0  NaN  1.0
# 70  1.0  NaN  1.0
# 75  1.0  NaN  1.0
# 80  1.0  NaN  1.0
# 85  1.0  NaN  1.0
# 90  1.0  NaN  1.0

# %%
decrease_power = -10
increase_power = 50

results = pd.concat([target_trend, votes], axis=1)
results = results.assign(power = votes.abs())

direction = results['votes'] > 0
is_vote = (
    (results[target] == False) & (results['votes'] <= decrease_power) |
    (results[target] == True) & (results['votes'] >= increase_power)
)
# is_vote = (results[target] == direction) & (results['power'] > t)
guess = results[target][is_vote]

# results[f'direction_{t}'] = direction
# results[f'is_vote_{t}'] = is_vote
results[f'guess'] = guess
results[f'shift'] = results[f'guess'].shift(1)
results[f'out'] = results[f'shift'] == results[target]
results[f'out'] = results[f'out'][~results[f'shift'].isna()]
results[f'inc'] = results[f'out'][results[f'shift'] == True]
results[f'dec'] = results[f'out'][results[f'shift'] == False]
results = results.drop(columns = [f'guess', f'shift'])
results
# Out:
#              AAPL  votes  power   out   inc   dec
# Date
# 2024-12-31  False -100.0  100.0   NaN   NaN   NaN
# 2025-01-03  False   90.0   90.0  True   NaN  True
# 2025-01-06  False  -10.0   10.0   NaN   NaN   NaN
# 2025-01-09  False  -80.0   80.0   NaN   NaN   NaN
# 2025-01-12  False   60.0   60.0  True   NaN  True
# 2025-01-15  False   60.0   60.0   NaN   NaN   NaN
# 2025-01-21  False   50.0   50.0   NaN   NaN   NaN
# 2025-01-24  False    0.0    0.0   NaN   NaN   NaN
# 2025-01-27   True  -30.0   30.0   NaN   NaN   NaN
# 2025-01-30  False   30.0   30.0   NaN   NaN   NaN
# 2025-02-02  False  -10.0   10.0   NaN   NaN   NaN
# 2025-02-05  False  -10.0   10.0   NaN   NaN   NaN
# 2025-02-08   True   50.0   50.0   NaN   NaN   NaN
# 2025-02-11   True   30.0   30.0  True  True   NaN

# %%
final = pd.concat([
    results.loc[:, results.columns.str.contains('out')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('inc')].mean(axis=0).reset_index(drop=True),
    results.loc[:, results.columns.str.contains('dec')].mean(axis=0).reset_index(drop=True),
], axis=1, ignore_index=True)
final.columns = ['out', 'inc', 'dec']
final.index = results.loc[:, results.columns.str.contains('out')].mean(axis=0).index.str.replace('out_', '')
final
# Out:
#      out  inc  dec
# out  1.0  1.0  1.0
