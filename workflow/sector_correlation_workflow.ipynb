# %%
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels as sm
from pathlib import Path
import yfinance as yf
from tqdm import tqdm
import seaborn as sns
import matplotlib.pyplot as plt

from correlation_helper import *

# %%
# initialize workflow parameters
data_path1 = Path('../data/pearson_matrix_2024-01-01_2025-01-01_top20.csv').resolve()

data_path2 = Path('../data/top_20_companies_by_sector.csv').resolve()
market_ticker = '^GSPC'
analysis_start = "2024-01-01"
analysis_end = "2025-01-01"

# import data
data1 = pd.read_csv(data_path1)
data2 = pd.read_csv(data_path2)

# Download Stock Data
stock_data = yf.download(data2['Symbol'].to_list(), start=analysis_start, end=analysis_end).dropna(axis=1, how='all')['Close']
stock_data.head()

data1
data2
# Out:
# [*********************100%***********************]  233 of 233 completed
#
# 6 Failed downloads:
# ['USGOW', 'DHCNL', 'NIOBW', 'HYMCW', 'MVSTW']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-01-01 -> 2025-01-01)')
# ['SFD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1704085200, endDate = 1735707600")')
#     Symbol                                        Name Last Sale  Net Change  \
# 0     UFPI            UFP Industries Inc. Common Stock   $115.67       -0.79
# 1     AMWD  American Woodmark Corporation Common Stock    $77.01        0.48
# 2      IPX  IperionX Limited American Depositary Share    $26.52        0.12
# 3       EU           enCore Energy Corp. Common Shares     $2.91        0.06
# 4     USGO           U.S. GoldMining Inc. Common stock    $12.59        1.78
# ..     ...                                         ...       ...         ...
# 228    NNE       Nano Nuclear Energy Inc. Common Stock    $32.20       -2.91
# 229   MSEX        Middlesex Water Company Common Stock    $50.57        1.18
# 230   NTGR                   NETGEAR Inc. Common Stock    $30.91        0.56
# 231   ADTN           ADTRAN Holdings Inc. Common Stock    $11.07       -0.28
# 232   CLNE       Clean Energy Fuels Corp. Common Stock     $3.28       -0.12
#
#     % Change  Market Cap (B)        Country  IPO Year   Volume  \
# 0    -0.678%        7.024022  United States    1993.0   223820
# 1     0.627%        1.159322  United States    1986.0   168642
# 2     0.455%        0.682213  United States       NaN    50560
# 3     2.105%        0.541518  United States       NaN  1091464
# 4    16.466%        0.156678  United States    2023.0   225247
# ..       ...             ...            ...       ...      ...
# 228  -8.288%        1.178419  United States    2024.0  4672623
# 229   2.389%        0.902937  United States       NaN    66512
# 230   1.845%        0.889273  United States    2003.0   526859
# 231  -2.467%        0.877286  United States    1994.0   595084
# 232  -3.529%        0.732937  United States    2007.0  2029891
#
#               Sector                      Industry
# 0    Basic Materials               Forest Products
# 1    Basic Materials               Forest Products
# 2    Basic Materials     Other Metals and Minerals
# 3    Basic Materials     Other Metals and Minerals
# 4    Basic Materials               Precious Metals
# ..               ...                           ...
# 228        Utilities   Electric Utilities: Central
# 229        Utilities                  Water Supply
# 230        Utilities  Telecommunications Equipment
# 231        Utilities  Telecommunications Equipment
# 232        Utilities      Natural Gas Distribution
#
# [233 rows x 11 columns]
