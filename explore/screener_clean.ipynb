# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import tqdm
from pathlib import Path

# %%
# Read data
screener_path  = Path('../data/nasdaq_screener_20250513.csv')
screener = pd.read_csv(screener_path)
screener
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $115.55
# 1        AA                    Alcoa Corporation Common Stock     $28.12
# 2      AACB  Artius II Acquisition Inc. Class A Ordinary Sh...     $9.97
# 3     AACBR                  Artius II Acquisition Inc. Rights    $0.205
# 4     AACBU                   Artius II Acquisition Inc. Units    $10.15
# ...     ...                                                ...       ...
# 6876   ZVSA             ZyVersa Therapeutics Inc. Common Stock   $0.5398
# 6877    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $37.20
# 6878   ZYBT  Zhengye Biotechnology Holding Limited Ordinary...   $13.425
# 6879   ZYME                        Zymeworks Inc. Common Stock    $12.02
# 6880   ZYXI                            Zynex Inc. Common Stock     $2.15
#
#       Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# ...

# %%
screener.columns
# Out:
# Index(['Symbol', 'Name', 'Last Sale', 'Net Change', '% Change', 'Market Cap',
#        'Country', 'IPO Year', 'Volume', 'Sector', 'Industry'],
#       dtype='object')

# %%
# Select top 500 stocks by market cap
screener.sort_values('Market Cap', ascending=False).head(500)['Sector'].value_counts()
# Out:
# Sector
# Consumer Discretionary    89
# Technology                87
# Finance                   87
# Industrials               55
# Health Care               46
# Utilities                 36
# Energy                    29
# Real Estate               23
# Consumer Staples          20
# Telecommunications        13
# Basic Materials           10
# Miscellaneous              1
# Name: count, dtype: int64

# %%
# Screener cleaning
#   Keep stocks with 
cleaned = screener.dropna()
cleaned
# Out:
#      Symbol                                               Name Last Sale  \
# 0         A             Agilent Technologies Inc. Common Stock   $115.55
# 1        AA                    Alcoa Corporation Common Stock     $28.12
# 4     AACBU                   Artius II Acquisition Inc. Units    $10.15
# 5      AACG   ATA Creativity Global American Depositary Shares   $0.9897
# 10     AAMI         Acadian Asset Management Inc. Common Stock    $30.08
# ...     ...                                                ...       ...
# 6872   ZUMZ                           Zumiez Inc. Common Stock    $13.31
# 6874   ZVIA                     Zevia PBC Class A Common Stock     $2.72
# 6876   ZVSA             ZyVersa Therapeutics Inc. Common Stock   $0.5398
# 6877    ZWS  Zurn Elkay Water Solutions Corporation Common ...    $37.20
# 6878   ZYBT  Zhengye Biotechnology Holding Limited Ordinary...   $13.425
#
#       Net Change % Change    Market Cap         Country  IPO Year    Volume  \
# ...

# %%
# Select top 500 stocks by market cap
selected = cleaned.sort_values('Market Cap', ascending=False).head(500).reset_index(drop=True)
selected
# Out:
#     Symbol                                             Name Last Sale  \
# 0     MSFT               Microsoft Corporation Common Stock   $449.26
# 1     AAPL                          Apple Inc. Common Stock   $210.79
# 2     NVDA                  NVIDIA Corporation Common Stock   $123.00
# 3     AMZN                     Amazon.com Inc. Common Stock   $208.64
# 4     GOOG              Alphabet Inc. Class C Capital Stock   $159.58
# ..     ...                                              ...       ...
# 495   KNTK       Kinetik Holdings Inc. Class A Common Stock    $43.33
# 496     FR  First Industrial Realty Trust Inc. Common Stock    $51.31
# 497   STEP        StepStone Group Inc. Class A Common Stock    $58.44
# 498   BBIO               BridgeBio Pharma Inc. Common Stock    $35.68
# 499   VOYA                 Voya Financial Inc. Common Stock    $69.78
#
#      Net Change % Change    Market Cap        Country  IPO Year     Volume  \
# ...

# %%
selected.to_csv('../data/top_stocks_500.csv')
